# %% [markdown]
# ## Steps

# %% [markdown]
# ## Create Modelling.ipynb
# ---
# #### 1. Importing libraries
# #### 2. Load data
# #### 3. Check missing values
# #### 4. Split data to feature and target
# #### 5. Scale the features
# #### 6. Split data for modelling
# #### 7. Modelling
# - Put models in list: `models {list of all model to train with}`
# - Loop through the models:
#     - fit with `x_train` and `y_train`
#     - predict `y_pred = model.predict(X_test)`
#     - find accuracy score
#     - print model name with accuracy
#     - print confusion matrix using `ConfusionMatrixDisplay` to plot
# - Print table to show all the model performance
# #### 8. Hyper parameter turning
# - choose best model
# - set params
# - use `RandomsearchCV` to find and show best tunning by fit on `X_train, y_train`
# - find and show cross-validation of our best model
# - find and show the mean of cross-validation (use `np.mean`)
# #### 9. Predict with the tuned model (Best)
# `y_pred_best.predict(X_test)`
# #### 10. Save both best_model and scaler into pkl file (joblib)
# ---
# ## 🧩 create whine_app.py
#
# - import necessary libraries
# - initiate fastapi
# - load your pkl data (the one from modelling):
#     - `model = joblib.load('best_model.pkl')`
#     - `scaler = joblib.load('scaler.pkl')`
#
# #### Create inputmodel using BaseModel
#
# #### Create get api for homepage
#
# - display welcome message
#
# #### Create post api for prediction (features: Inputmodel)
#
# - convert features in 2d array (`np.array([[features list]])`)
# - scaled the feature (`scaler.transform(features)`)
# - make prediction with your model: `pred = model.predict(scaled_features)`
# - return `pred[0]`
#
# #### Run the app
#
# `uvicorn wineapp:app --reload`
